# %% [markdown]
# ----
# #  What is **Python**?
# ----
# - Python is a **popular, high-level** programming language known for its simplicity and **readability**.
# - It is used in many areas, including web development, data science, artificial intelligence, machine learning, scripting, automation, and more.
# - Python's syntax is clear and **easy** to learn for beginners.
# - Python is a popular programming language. It was created by **Guido van Rossum**, and released in 1991.

# %% [markdown]
# # Applications include:
#  - Data analysis and visualization
#  - Web and internet development
#  - Machine learning and AI
#  - Robotics and automation
#  - Game development
#  - Scripting and process automation

# %% [markdown]
# # Why Python
#
# - Works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc…)
# - Simple syntax similar to the English language.
# - Has syntax that allows developers to write programs with fewer lines than some other programming languages.
# - Runs on an interpreter system, meaning that code can be executed as soon as it is written. This means that prototyping can be very quick
# - Can be treated in a procedural way, an object-oriented way or a functional way.
# - Python was designed for readability, and has some similarities to the English language with influence from mathematics.
# - Python uses new lines to complete a command, as opposed to other programming languages which often use semicolons or parentheses.
# - Python relies on indentation, using whitespace, to define scope; such as the scope of loops, functions and classes. Other programming languages often use curly-brackets for this purpose.

# %% [markdown]
# # Installing Python
# - Visit the official Python website (https://python.org) and download the latest version for your operating system.
# - You can download the official Python installer from the Python.org downloads page. Choose the latest stable version for your operating system (Windows, macOS, Linux).
# - After installation, verify in your command prompt or terminal:
# - `python --version`
#  or
#  `python3 --version`

# %%
import sys       #sys  is a built-in Python library that provides system-specific parameters and functions.
print("Python version")
print(sys.version)
print("Version info.")
print(sys.version_info)
# Out:
# Python version
# 3.13.2 (tags/v3.13.2:4f8bb39, Feb  4 2025, 15:23:48) [MSC v.1942 64 bit (AMD64)]
# Version info.
# sys.version_info(major=3, minor=13, micro=2, releaselevel='final', serial=0)

# %% [markdown]
# # Installing IDEs
# - IDE stands for Integrated Development Environment, which helps you write, debug, and run code easily.
# - Popular IDEs for Python:
# ### 1. Jupyter Notebook
#     - Specially useful for data science, interactive code, explanations, and visualizations.
#     - Install with: pip install notebook
#     - Run with: jupyter notebook
# ### 2. Visual Studio Code (VS Code)
#     - Lightweight, extensible editor.
#     - Download from: https://code.visualstudio.com/
#     - Install Python extension in VS Code for Python coding.

# %% [markdown]
# ----
# # Running Python Scripts
# - You can write Python scripts in files with the '.py' extension.
# - To run a script, open a terminal and use:
#  python script_name.py
#  or
#  python3 script_name.py
# - You can also run code interactively in IDEs like Jupyter or the Python shell.

# %% [markdown]
# # Writing Your First Python Program

# %%
# Let's write a simple program that prints a message to the screen.
print("Hello, World!")  # This will print 'Hello, World!' to the output.
# Out:
# Hello, World!

# %% [markdown]
# # Python Interactive Shell Basics
# - The interactive shell (also called REPL: Read-Eval-Print Loop) lets you execute Python commands one at a time.
# - To start the shell, type `python` or `python3` in your command prompt or terminal.
# ### Example:
# - > print("Hello from shell!")
# - You will see: Hello from shell!
# - You can use the shell to quickly test ideas, calculations, or debug code.

# %% [markdown]
# # Python Indentation
#
# > Indentation refers to the spaces at the beginning of a code line.
#
# > Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
#
# > Python uses indentation to indicate a block of code.
#
#
# - Python uses indentation to define code blocks instead of braces {} like other languages. Indentation is crucial because it groups statements and controls program flow.
#
# - Use 4 spaces per indentation level (PEP 8 style guide recommendation).
#
# - Consistent indentation is required; mixing tabs and spaces causes errors.

# %%
if True:
    print("This is indented inside the if block")
    print("Both lines belong here")
print("This is outside the if block")
# Python Indentation
# Out:
# This is indented inside the if block
# Both lines belong here
# This is outside the if block

# %% [markdown]
# # Comments
# - Used to explain Python code.
# - Used to make the code more readable.
# - Used to prevent execution when testing code.
# - Comments starts with a #, and Python will ignore them, for multiple lines

# %% [markdown]
# ## Python - an interpreted language
# Python is called an interpreted language because its code is executed line-by-line at runtime by an interpreter

# %%
print("Step 1")

x = 10
y = 0

print("Step 2")

result = x / y   # This will cause an error

print("Step 3")  # This line will NOT execute
# Out:
# Step 1
# Step 2
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 8
#       4 y = 0
#       5
#       6 print("Step 2")
#       7
# ----> 8 result = x / y   # This will cause an error
#       9
#      10 print("Step 3")  # This line will NOT execute
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Python - dynamically typed
# Python is called dynamically typed because the type of a variable is determined at runtime, not when you write the code.

# %%
x = 10        # x is int
print(type(x))

x = "Hello"   # now x is string
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# The same variable x changes type during execution

# %%
a = 5
b = 2.5
c = a + b

print(c)
print(type(c))
# Out:
# 7.5
# <class 'float'>

# %% [markdown]
# No type declaration needed

# %% [markdown]
# ## Python is case sensitive
# It treats uppercase and lowercase letters as different identifiers.
#
# 👉 In simple terms:
# name, Name, and NAME are three different variables.

# %%
name = "Shahma"
Name = "Teacher"

print(name)
print(Name)
# Out:
# Shahma
# Teacher
