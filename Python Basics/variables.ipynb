# %% [markdown]
# #**Variables**

# %%
player="Messi"

# %%
name , age ,location , number = "shakkira" ,25, "thavanur", 2345678901
print(number)
name
# Out:
# 2345678901
# 'shakkira'

# %% [markdown]
# ##**Rules for naming variables**
#
#   1. Must start with a letter or underscore`_`
#   2. cannot start with a number
#   3. can contain letters,digits and underscores
#   4. Case-sensitive (`Name`=!`name`)
#   5. Sould not use Python keywords (`if`,`for`,`class`,etc.)

# %%
X = 10                   #Assign
name="alice"
_price= 99.99
is_active= True
print(X, name,_price, is_active)
# Out:
# 10 alice 99.99 True

# %%
name='Adham'
name
print(name)
print("name")
print("my name is",name)
print("my name is", name,"people call me",name)
print(type(X))   #calling the typenam of variable
print(type(name))
# Out:
# Adham
# name
# my name is Adham
# my name is Adham people call me Adham
# <class 'int'>
# <class 'str'>
