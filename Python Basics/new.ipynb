# %%
len=int(input("length of rectangle:"))
wid=int(input("width of rectangle:"))
if len==wid==0:
    print("it is point")
elif len==0 or wid==0:
    print("it is a line")
elif len==wid:
    print("it is a square")
else:
    print("it is retangle")
# Out:
# it is point

# %%
balance=30000
pin=1234
pinnum=int(input("enter your pin"))

if pin==pinnum:
    amount=int(input("amount to withdraw:"))
    
    if amount<=balance: 
        print("Transaction successfull")
        print(f"balance amount:{balance-amount}")
    else:
        print("insufficient balance")
else:
    print("wrong pin number")
# Out:
# Transaction successfull
# balance amount:10000

# %%
pin="1234"
balance=30000
d=input("enter pin")
if pin==d:
    x="1= check balance"
    y="2= deposite"
    z="withdrawal"
    print(x)
    print(y)
    print(z)
    choice=int(input("enter your choice:"))
    if choice==1:
        print(balance)
    elif choice==2:
        e=int(input("deposite amount:"))
        balance+=e
        print("balance:",balance)
    elif choice==3:
        c=int(input("enter your amount :"))
        if c<=acc_balance:
         print("transaction successfull")
         acc_balance-=c
         print("your balance :",acc_balance)
        else:
         print("insufficient balance")
    else:
       print("invalid choice")   
else:
  print("invalid pin number")
# Out:
# 1= check balance
# 2= deposite
# withdrawal
# balance: 40000

# %%
h=float(input("Enter your height:"))
w=float(input("Enter your weight"))
bmi=w/h**2
if bmi<18.5:
    print("under weight")
elif bmi<25:
    print("normal weight")
elif bmi<30:
    print("overweight")
else:
    print("obese")
# Out:
# under weight

# %%
unit=float(input("enter the used current"))
if unit<100:
    bill=unit*5
    print("bill:",bill)
elif unit<200:
    bill=100*5+(unit-100)*10     #eg:-unit:130,bill=100*5+30*10
    print("bill:",bill) 
else:
    bill=100*5+100*10+(unit-200)*20     #unit:500,bill=100*5+100*10+300*20
    print("bill:",bill)
# Out:
# bill: 300.0

# %%
name=input("enter your name:")
age=int(input("Enter your age:"))
if age<5:
    print("ticket rate:50")
elif age>60:
    print("ticket amount:100")
else:
    print("ticket:200")
# Out:
# ticket:200

# %%
total=int(input("enter total members:"))
children=int(input("enter the number of children age less than 5"))
senior=int(input("senior"))
if (children+senior)<total:
    sum=children*0+senior*100+(total-(children+senior))*200
    print(sum)
else:
    print("wrong input")
# Out:
# wrong input

# %%
name=input("enter your name:")
adhr=input("do you have adhaar:")


if adhr=="yes":
    print("adhaar is available")
    pan=input("do you have pan card")
    if pan=="yes":
        print("pan card is available")
        birth=input("do you have birth certificate")
        if birth=="yes":
            print("your eligible for passport")
        else:
            print("birth certificate is not verified")
    else:
        print("pancard is not verified")
else:
    print("not eligible")
# Out:
# adhaar is available
# pancard is not verified
