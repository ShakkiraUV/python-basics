# %% [markdown]
# # **Conditional statements**
#
# Conditional statements help programs make decisions.
#
# In Python, we mainly use:
#
# - if
# - if-else
# - if-elif-else
# - Nested if
# - Multiple conditions using and, or, not

# %% [markdown]
# ## **if**

# %% [markdown]
# * You can write an if statement in one line if it has only one action.

# %% [markdown]
# ```
# if condition:
#     statement
# ```

# %%
age = 20

if age >= 18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %% [markdown]
# - Condition checked: age >= 18
# - If condition is True, block executes

# %%
num = int(input("Enter a number: "))
print("Number: ",num)

if num > 0:
    print("Positive Number")
# Out:
# Number:  67
# Positive Number

# %%
x=10
if x > 5:
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
x=10
if x>5: print("x is greater than 5")
# Out:
# x is greater than 5

# %% [markdown]
# Executes only if condition is True

# %% [markdown]
# ## **if–else**

# %% [markdown]
# Used when there are two possible outcomes.

# %% [markdown]
# ```
# Used when there are two possible outcomes.
# ```

# %% [markdown]
# ```
# if condition:
#     statements
# else:
#     statements
# ```

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %%
"even" if num%2==0 else "odd"
# Out:
# 'odd'

# %%
# Voting Eligibility

age = int(input("Enter your age: "))

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Eligible to vote

# %%
# pass or fail

marks = int(input("Enter marks: "))

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %% [markdown]
# ## **if - elif - else**

# %% [markdown]
# Used when there are multiple conditions.
#
#
#
# ```
# if condition1:
#     statements
#
# elif condition2:
#     statements
#
# elif condition3:
#     statements
#
# else:
#     statements
# ```

# %%
a,b=10,20
if a==b:
    print("Equal")
elif a>b:
    print("a is bigger")
else:
    print("b is bigger")
# Out:
# b is bigger

# %%
'equal' if a==b else 'a is bigger' if a>b else 'b is bigger'
# Out:
# 'b is bigger'

# %%
# Largest of Three Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("A is largest")

elif b > a and b > c:
    print("B is largest")

else:
    print("C is largest")
# Out:
# B is largest

# %% [markdown]
# Using shorthand for printing directly

# %%
num = -3
print("Positive" if num > 0 else "Negative")
# Out:
# Negative

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")

elif marks >= 75:
    print("Grade B")

elif marks >= 50:
    print("Grade C")

else:
    print("Fail")
# Out:
# Grade B

# %% [markdown]
# With logical conditions

# %%
age = 18
print("Eligible" if age >= 18 and age <= 60 else "Not Eligible")
# Out:
# Eligible

# %%
# Check eligibility

age = 25
income = 30000

if age >= 18 and income >= 20000:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Eligible

# %%
# Traffic Signal Program

signal = input("Enter signal color: ")

if signal == "red":
    print("Stop")

elif signal == "yellow":
    print("Get Ready")

elif signal == "green":
    print("Go")

else:
    print("Invalid Signal")
# Out:
# Get Ready

# %% [markdown]
# ## **Nested if**

# %% [markdown]
# An if inside another if
#
#
# ```
# if condition1:
#
#     if condition2:
#         statements
# ```

# %%
# Check positive AND even

num = 8

if num > 0:
    print("Positive number")

    if num % 2 == 0:
        print("Even number")
    else:
        print("Odd number")

else:
    print("Negative number")
# Out:
# Positive number
# Even number

# %%
# Login system

username = "admin"
password = "1234"

if username == "admin":
    if password == "1234":
        print("Login successful")
    else:
        print("Wrong password")
else:
    print("Invalid username")
# Out:
# Login successful

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin":

    if password == "1234":
        print("Login Successful")

    else:
        print("Wrong Password")

else:
    print("Invalid Username")
# Out:
# Login Successful

# %%
# Eligible for Scholarship

marks = int(input("Enter marks: "))
income = int(input("Enter family income: "))

if marks >= 80:

    if income < 300000:
        print("Eligible for scholarship")

    else:
        print("Income too high")

else:
    print("Marks too low")
# Out:
# Eligible for scholarship

# %%
# ATM Example

balance = 5000
amount = int(input("Enter withdrawal amount: "))

if amount <= balance:

    if amount % 100 == 0:
        print("Transaction Successful")

    else:
        print("Amount should be multiple of 100")

else:
    print("Insufficient Balance")
# Out:
# Transaction Successful

# %% [markdown]
# # Using Logical Operators

# %%
age = int(input("Enter age: "))
citizen = input("Are you a citizen (yes/no)? ")

if age >= 18 and citizen == "yes":
    print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# Eligible to vote

# %%
day = input("Enter day: ")

if day == "Saturday" or day == "Sunday":
    print("Weekend")
else:
    print("Weekday")
# Out:
# Weekday

# %%
logged_in = False

if not logged_in:
    print("Please login")
# Out:
# Please login

# %% [markdown]
# # PRACTICE QUESTIONS AND ANSWERS

# %% [markdown]
# 1. Input score and print "Pass with distinction" if ≥85, "Pass" if 40–84, else "Fail".

# %%
score=int(input("Enter score"))
"pass with distinction" if score>=85 else "pass" if score>=40 and score<=84 else "Fail"
# Out:
# 'pass'

# %%
score=int(input("Enter score"))
if score>=85:
  print("pass with distinction")
elif score>=40 and score<=84:
  print("pass")
else:
  print("fail")
# Out:
# fail

# %% [markdown]
# 2. Input a number and print "Even and >10" if both conditions are true, else "No".

# %%
num=int(input("Enter a number"))
"even and >10" if num%2==0 and num>10 else "No"
# Out:
# 'even and >10'

# %% [markdown]
# 3. Input age and print "Teen" if 13–19, else "Not Teen".

# %%
age=int(input("Enter age"))
"Teen" if 13<=age<=19 else "Not Teen"
# Out:
# 'Teen'

# %%
age=int(input("Enter age"))
"Teen" if age>=13 and age<=19 else "Not Teen"
# Out:
# 'Not Teen'

# %% [markdown]
# 4. Input three numbers and print whether all are equal, any two are equal, or all different.

# %%
n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
n3=int(input("Enter third number"))

"equal" if n1==n2==n3 else "two are equal" if n1==n2 or n1==n3 or n2==n3 else "All different"
# Out:
# 'All different'

# %% [markdown]
# 5. Input a number and print "Fizz" if divisible by 3, "Buzz" if divisible by 5, "FizzBuzz" if both, else the number itself.

# %%
num=int(input("Enter a number"))
"fizzbuzz" if num%3==0 and num%5==0 else "fizz" if num%3==0 else "buzz" if num%5==0 else num
# Out:
# 'buzz'

# %% [markdown]
# 6. Input a string and print "Empty" if it’s an empty string, else "Not Empty".

# %%
name=input("Enter a name")
"empty" if len(name)==0 else "not empty"
# Out:
# 'empty'

# %% [markdown]
# 7. Input two numbers and print "Both Even", "One Even", or "None Even".

# %%
num1=int(input("Enter a number"))
num2=int(input("Enter second number"))
"Both even" if num1%2==0 and num2%2==0 else "One even" if num1%2==0 or num2%2==0 else "None even"
# Out:
# 'One even'

# %% [markdown]
# 8. Input username & password → print "Login Successful" if both match stored values else "Access Denied".

# %%
org_username="aswathi28"
org_pass=123456
user=input("Enter the username")
pasw=int(input("Enter the password"))
"Login Successfull" if user==org_username and pasw==org_pass else "Access Denied"
# Out:
# 'Access Denied'

# %% [markdown]
# ## Nested if

# %% [markdown]
# * A nested if means placing one if statement inside another.

# %% [markdown]
# 1. Check if a number is positive and even

# %%
num=int(input("Enter a number"))
if num>0:
    if num%2==0:
        print(f"{num} is even and positive")
    else:
        print(f"{num} is odd and positive")
else:
    print("Number is negative")
# Out:
# 34 is even and positive

# %% [markdown]
# 2. Check if student passed and scored distinction

# %%
score=int(input("Enter the score"))
if score>=30:
    if score>=90:
        print("Student passed with distinction")
    else:
        print("Student passed")
else:
    print("Fail")
# Out:
# Student passed

# %% [markdown]
# 3. Check if a character is an alphabet. If yes, then check whether it’s vowel or consonant.

# %%
ch=input("Enter a character")
if ch.isalpha():
    if ch in 'AEIOUaeiou':
        print("ITS A ALPHABET AND IT IS A VOWEL")
    else:
        print("IT'S AN ALPHABET AND ITS A CONSONANT")
else:
    print("NOT AN ALPHABET")
# Out:
# ITS A ALPHABET AND IT IS A VOWEL

# %% [markdown]
# 4. Check if a person is eligible for driving license:
#
# Age ≥18 → check if eyesight is “Good” → "Eligible" else "Not Eligible".

# %%
age=int(input("Enter age"))
eyesight=input("Tell about your eyesight is it good or bad")
if age>=18:
    if eyesight.lower()=='good':
        print("Eligible for driving licence")
    else:
        print("Not eligible")
else:
    print("Not eligible")
# Out:
# Eligible for driving licence

# %% [markdown]
# 5. Input a number and check if it’s divisible by 2, and if yes, check if it’s also divisible by 3

# %%
num=int(input("Enter a number"))
if num%2==0:
    if num%3==0:
        print("IT IS DIVISIBLE BY BOTH 2 AND 3")
    else:
        print("ONLY DIVISIBLE BY 2")
else:
    print("NOT DIVISIBLE BY 2")
# Out:
# IT IS DIVISIBLE BY BOTH 2 AND 3

# %% [markdown]
# 6. Input three angles →
#
#     * If sum = 180 → "Valid triangle"
#
#         * If all angles equal → "Equilateral"
#
#         * Else if any two equal → "Isosceles"
#
#         * Else → "Scalene"
#
#     * Else → "Invalid triangle".

# %%
angle1=float(input("Enter angle1"))
angle2=float(input("Enter angle2"))
angle3=float(input("Enter angle3"))

if angle1+angle2+angle3==180:
    print("VALID TRIANGLE")
    if angle1==angle2==angle3:
        print("TRIANGLE IS EQUILATERAL")
    elif angle1==angle2 or angle1==angle3 or angle2==angle3:
        print("TRIANGLE IS ISOSCELES")
    else:
        print("TRIANGLE IS SCALENE")
else:
    print("NOT A VALID TRAINGLE")
# Out:
# VALID TRIANGLE
# TRIANGLE IS SCALENE

# %%
angle1=float(input("Enter angle1"))
angle2=float(input("Enter angle2"))
angle3=float(input("Enter angle3"))

if angle1+angle2+angle3==180:
    print("VALID TRIANGLE")
    print("EQUILATERAL" if angle1==angle2==angle3 else "ISOSCELES" if angle1==angle2 or angle1==angle3 or angle2==angle3 else "SCALENE")
else:
    print("NOT A VALID TRIANGLE")
# Out:
# NOT A VALID TRIANGLE

# %% [markdown]
# # IF-ELSE QUESTIONS

# %% [markdown]
# 1. Write a program to check if a number is positive or negative.

# %%
num=int(input("Enter a number to check"))
if num>0:
    print("its a positive number")
else:
    print("Its a negative number")                  # here in this if we enter 0 it will also considered as negative
# Out:
# its a positive number

# %% [markdown]
# 2. Check whether a number is even or odd.

# %%
n=int(input("Enter a number:"))
if n%2==0:
    print(f"{n} is an even number")
else:
    print(f"{n} is an odd number")
# Out:
# 87 is an odd number

# %% [markdown]
# 3. Find the largest of two numbers.

# %%
num1=int(input("Enter first number"))
num2=int(input("Enter second number"))
if num1>num2:
    print(f"{num1} is the largest number")
else:
    print(f"{num2} is the largest number")
# Out:
# 87 is the largest number

# %% [markdown]
# 4. Check if a number is divisible by 5 and 10.

# %%
num=int(input("enter a number"))
if num%5==0 and num%10==0:
    print(f"{num} is divisible by both 5 and 10")
else:
    print(f"{num} is not divisible by both 5 and 10")
# Out:
# 25 is not divisible by both 5 and 10

# %% [markdown]
# 5. Input a year and check whether it is a leap year.

# %% [markdown]
#    * A leap year is a year that contains 366 days instead of the usual 365, with an extra day added to February (February 29).
#
#    * A year is a leap year if:
#
#         * It is divisible by 4 AND
#
#           * Not divisible by 100, unless it is also divisible by 400.

# %%
y=int(input("Enter a year"))
if (y%4==0 and y%100!=0) or y%400==0:
    print(f"{y} is a leap year")
else:
    print(f"{y} is not a leap year")
# Out:
# 2012 is a leap year

# %% [markdown]
# 6. Take a character as input and check if it is a vowel or consonant.

# %%
ch=input("Enter a character ")
if ch in 'AEIOUaeiou':
    print(f"{ch} is a vowel")
else:
    print(f"{ch} is a consonant")
# Out:
# t is a consonant

# %%
ch=input("Enter a character ")
vow=['A','E','I','O','U','a','e','i','o','u']
if ch in vow:
    print(f"{ch} is a vowel")
else:
    print(f"{ch} is a consonant")
# Out:
# i is a vowel

# %% [markdown]
# 7. Take an integer input and check if it is a single-digit, double-digit, or triple-digit number.

# %%
n=int(input("Enter a number"))
if len(str(n))==1:
    print(f"{n} is a single digit number")
elif len(str(n))==2:
    print(f"{n} is a double digit number")
elif len(str(n))==3:
    print(f"{n} is a triple digit number")
else:
    print("The number contains more than 1 digit")
# Out:
# 5 is a single digit number

# %% [markdown]
# 8. Check if a person is eligible to vote (age ≥ 18).

# %%
name=input("Enter your name")
age=int(input("Enter your age"))
if age>=18:
    print(f"{name}, you are eligible for voting")
else:
    print(f"{name}, you are not eligible for voting")
# Out:
# shakkira, you are eligible for voting

# %% [markdown]
# 9. Check if a number is zero, positive, or negative.

# %%
num=int(input("Enter a number to check"))
if num>0:
    print("its a positive number")
elif num<0:
    print("Its a negative number")
else:
    print(f"Its a zero")
# Out:
# its a positive number

# %% [markdown]
# 10. Find the largest among three numbers using if–else.

# %%
n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
n3=int(input("Enter third number"))

if n1>n2 and n1>n3:
    print(f"{n1} is the largest number")
elif n2>n1 and n2>n3:
    print(f"{n2} is the largest number")
else:
    print(f"{n3} is the largest")
# Out:
# 56 is the largest number

# %% [markdown]
# 11. Input marks and print the grade according to the following:
#
# ≥90: A
#
# 80–89: B
#
# 70–79: C
#
# 60–69: D
#
# <60: Fail

# %%
mark=int(input("Enter your mark"))
if mark>=90:
    print("Grade A")
elif mark>=80 and mark<=89:
    print("Grade B")
elif mark>=70 and mark<=79:
    print("Grade C")
elif mark>=60 and mark<=69:
    print("Grade D")
else:
    print("Fail")
# Out:
# Grade A

# %% [markdown]
# 12. Check whether a given year is a century year (e.g., 1900, 2000).

# %%
year=int(input("Enter a year"))
if year%100==0:
    print(f"{year} is a century year")
else:
    print(f"{year} is not a century year")
# Out:
# 2013 is not a century year

# %% [markdown]
# 13. Check whether a given alphabet is uppercase, lowercase, digit, or special character.

# %%
alph=input("Enter an alphabet")
if alph.isupper():
    print(f"{alph} is in uppercase")
elif alph.islower():
    print(f"{alph} is in lowercase")
elif alph.isdigit():
    print(f"{alph} is a digit")
elif len(alph)==1:
    print("It is a special character")
else:
    print("not a valid one")
# Out:
# e is in lowercase

# %% [markdown]
# 14. Check if the last digit of a number is even or odd.

# %%
n=int(input("Enter a number"))
if int(str(n)[-1])%2==0:
    print("Last digit is even")
else:
    print("Last digit is an odd number")
# Out:
# Last digit is an odd number

# %% [markdown]
# 15. Check whether the entered number is a palindrome number (e.g., 121).

# %% [markdown]
#    * A palindrome is a word, number, phrase, or sequence that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.

# %%
num=int(input("Enter a number"))
if str(num)==str(num)[::-1]:
    print("Its a palindrome number")
else:
    print("Not a palindrome number")
# Out:
# Not a palindrome number

# %% [markdown]
# 16. Check whether the entered string is a palindrome or not.

# %%
string=input("Enter a string")
if string[::-1]==string:
    print("its a palindrome string")
else:
    print("Not a palindrome string")
# Out:
# its a palindrome string

# %% [markdown]
# Salary Bonus

# %%
salary = float(input("Enter salary: "))
experience = int(input("Enter years of experience: "))

if experience >= 5:
    bonus = salary * 0.10
    print(f"Bonus Amount = {bonus}")

else:
    print("No Bonus")
# Out:
# Bonus Amount = 2000.0

# %% [markdown]
# Electricity Bill Discount

# %%
bill = float(input("Enter electricity bill amount: "))

if bill > 5000:
    discount = bill * 0.05
    final_bill = bill - discount

    print(f"Discount = {discount}")
    print(f"Final Bill = {final_bill}")

else:
    print("No Discount")
# Out:
# No Discount

# %% [markdown]
# BMI Calculator

# %%
weight = float(input("Enter weight in kg: "))
height = float(input("Enter height in meters: "))

bmi = weight / (height ** 2)

print(f"BMI = {bmi:.2f}")

if bmi < 18.5:
    print("Underweight")

elif bmi < 25:
    print("Normal Weight")

elif bmi < 30:
    print("Overweight")

else:
    print("Obese")
# Out:
# BMI = 56.00
# Obese

# %% [markdown]
# Student Result System

# %%
name = input("Enter student name: ")

python_marks = int(input("Enter Python marks: "))
sql_marks = int(input("Enter SQL marks: "))
ml_marks = int(input("Enter ML marks: "))

total = python_marks + sql_marks + ml_marks
average = total / 3

print("\n===== RESULT =====")

print(f"Student Name : {name}")
print(f"Total Marks  : {total}")
print(f"Average      : {average:.2f}")

if average >= 90:
    print("Grade A")

elif average >= 75:
    print("Grade B")

elif average >= 50:
    print("Grade C")

else:
    print("Fail")
# Out:
# ===== RESULT =====
# Student Name : Adam
# Total Marks  : 170
# Average      : 56.67
# Grade C
